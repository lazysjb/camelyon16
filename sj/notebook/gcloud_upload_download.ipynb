# %%
import os
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm

# %%
# Using gsutil

# %%
TEMP_LOCAL_DIR = '../test/'

# %%
output_file_path = TEMP_LOCAL_DIR + 'test_kitten.png'
output_file_path
# Out:
# '../test/test_kitten.png'

# %%
# !gsutil cp gs://applied-dl-sj/testing/my_kitten.png $output_file_path
# Out:
# Copying gs://applied-dl-sj/testing/my_kitten.png...
# / [1 files][164.3 KiB/164.3 KiB]
# Operation completed over 1 objects/164.3 KiB.

# %%
os.listdir(TEMP_LOCAL_DIR)
# Out:
# ['test_kitten.png']

# %%
image = plt.imread(output_file_path)

# %%
plt.imshow(image)

# %%
source_dir = '/home/sjb/Projects/Columbia/Applied_DL/CamelyonProject/data/source_data'

# %%
dest_gc_dir = 'gs://applied-dl-sj/testing'

# %%
file_name = 'tumor_059.tif'

# %%
source_fp = os.path.join(source_dir, file_name)
dest_gc_fp  = os.path.join(dest_gc_dir, file_name)

# %%
source_fp, dest_gc_fp
# Out:
# ('/home/sjb/Projects/Columbia/Applied_DL/CamelyonProject/data/source_data/tumor_059.tif',
#  'gs://applied-dl-sj/testing/tumor_059.tif')

# %%
# !gsutil cp $source_fp $dest_gc_fp
# Out:
# Copying file:///home/sjb/Projects/Columbia/Applied_DL/CamelyonProject/data/source_data/tumor_059.tif [Content-Type=image/tiff]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# \
# Operation completed over 1 objects/1.4 GiB.

# %% [markdown]
# ### Actual File Upload

# %%
DEST_GC_DIR = 'gs://applied-dl-sj/camelyon/source_data'
SOURCE_DIR = '/home/sjb/Projects/Columbia/Applied_DL/CamelyonProject/data/source_data'

# %%
all_source_fps = glob(SOURCE_DIR + '/*')

# %%
# for source_fp in tqdm(all_source_fps):
#     source_filename = os.path.basename(source_fp)
#     dest_fp = os.path.join(DEST_GC_DIR, source_filename)
#     !gsutil cp $source_fp $dest_fp
