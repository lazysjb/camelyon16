# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

# %%
sys.path.append('../../')

# %%
from utils.evaluate import get_evaluation_metrics

# %%
output = get_evaluation_metrics('vgg16_transfer',
                                'zoom_1_256_256',
                                'test',)

# %%
output
# Out:
# {'accuracy': 0.9075647668393783,
#  'auc': 0.951589042256042,
#  'dummy_accuracy': 0.7389119170984456,
#  'loss': 0.2505052201210026,
#  'model_name': 'vgg16_transfer',
#  'precision': 0.8005540166204986,
#  'recall': 0.8602897400277832}
