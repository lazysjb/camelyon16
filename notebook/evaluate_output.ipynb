# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

# %%
sys.path.append('../')

# %%
from utils.evaluate import get_evaluation_metrics

# %% [markdown]
# ### Single Input VGG16 Transfer Learn Output

# %%
output_1 = get_evaluation_metrics('vgg16_transfer',
                                  'zoom_1_256_256',
                                  'test',)

# %%
output_1
# Out:
# {'accuracy': 0.9072731040198923,
#  'auc': 0.9519852128511525,
#  'dummy_accuracy': 0.7389660174057191,
#  'loss': 0.25251142874565596,
#  'model_name': 'vgg16_transfer',
#  'precision': 0.7982375619607123,
#  'recall': 0.8628696169874975}

# %% [markdown]
# ### Double Input VGG16 Transfer Learn Output

# %%
output_2 = get_evaluation_metrics('vgg16_transfer_double_input',
                                  'zoom_1_256_256',
                                  'test',)

# %%
output_2
# Out:
# {'accuracy': 0.9082050484631732,
#  'auc': 0.9557409829261325,
#  'dummy_accuracy': 0.7388171875809879,
#  'loss': 0.25995600929955465,
#  'model_name': 'vgg16_transfer_double_input',
#  'precision': 0.8097043214556482,
#  'recall': 0.8477872593768605}
